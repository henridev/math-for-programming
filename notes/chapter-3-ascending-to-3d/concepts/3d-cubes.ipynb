# %%
import sys
sys.path.insert(0,'..')
from plot3dcube import *;

plot3dcube((1,0,0), (0,1,0), (0,0,1))
# parallelepiped
plot3dcube((1,0.5,0), (0,1,0), (0.5,0,1))
# plane because columns are linearly dependent
plot3dcube((1,0.5,1), (0,1,0), (1,1.5,1))
